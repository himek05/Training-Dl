# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dataset = pd.read_csv('cust_satisfaction.csv')
dataset.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
dataset.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.duplicated().sum()
# Out:
# np.int64(172)

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
dataset["Customer Type"].value_counts()
# Out:
# Customer Type
# Loyal Customer       84517
# disloyal Customer    18905
# Name: count, dtype: int64

# %%
dataset['Gender'] = dataset['Gender'].map({"Male":1,"Female":0})
dataset['Customer Type'] = dataset['Customer Type'].map({"Loyal Customer":1,"Disloyal Customer":0})
dataset["Type of Travel"] = dataset["Type of Travel"].map({"Business travel":1,"Personal Travel":0})    
dataset["Class"] = dataset["Class"].map({"Business":1,"Eco":2,"Eco Plus":3})
dataset["satisfaction"] = dataset["satisfaction"].map({"satisfied":1,"neutral or dissatisfied":0})
dataset.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0       1            1.0               0      3             0   13
# 1       1            NaN               1      1             0   25
# 2       0            1.0               1      1             1   26
# 3       0            1.0               1      1             0   25
# 4       1            1.0               1      1             1   61
#
#    Flight Distance  Inflight entertainment  Baggage handling  Cleanliness  \
# 0              460                       5                 4            5
# 1              235                       1                 3            1
# 2             1142                       5                 4            5
# 3              562                       2                 3            2
# 4              214                       3                 4            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0

# %%
loyal_customer = dataset[dataset['Customer Type'] == 1].loc[0:2000]
disloyal_customer = dataset[dataset['Customer Type'] == 0]

# %%
balance_dataset = pd.concat([loyal_customer, disloyal_customer], axis=0)
balance_dataset.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0       1            1.0               0      3             0   13
# 2       0            1.0               1      1             1   26
# 3       0            1.0               1      1             0   25
# 4       1            1.0               1      1             1   61
# 5       0            1.0               0      2             0   26
#
#    Flight Distance  Inflight entertainment  Baggage handling  Cleanliness  \
# 0              460                       5                 4            5
# 2             1142                       5                 4            5
# 3              562                       2                 3            2
# 4              214                       3                 4            3
# 5             1180                       1                 4            1
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
# 5                           0                       0.0

# %%
x = balance_dataset.drop(['Customer Type'], axis=1)
y = balance_dataset['Customer Type']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_Scaled = scaler.fit_transform(x_train)
x_test_Scaled = scaler.transform(x_test)
# Out:
# C:\Users\himek\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()


model.add(Dense(68,activation = "relu",input_dim = x_train_Scaled.shape[1]))

model.add(Dense(32,activation = "relu"))
model.add(Dense(24,activation = "relu"))
model.add(Dense(16,activation = "relu"))

model.add(Dense(1,activation = "sigmoid"))

model.compile(loss = "binary_crossentropy",optimizer = "adam",metrics = ["accuracy"])
model.summary()
# Out:
# C:\Users\himek\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                     │ (None, 68)                  │             816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 32)                  │           2,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 24)                  │             792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 16)                  │             400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,233 (16.54 KB)
#  Trainable params: 4,233 (16.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping  

early_stopping = EarlyStopping(  
    monitor="val_loss",
    patience=3,
    restore_best_weights=True  
)

history = model.fit(
    x_train_Scaled, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(x_test_Scaled, y_test),  
    callbacks=[early_stopping]  
)
# Out:
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8486 - loss: 0.5045 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 1.7268e-04
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 4.0642e-05
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 1.5030e-05
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.3653e-04 - val_accuracy: 1.0000 - val_loss: 6.7581e-06
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.0107e-04 - val_accuracy: 1.0000 - val_loss: 3.5879e-06
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.0057e-04 - val_accuracy: 1.0000 - val_loss: 2.0658e-06
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.0732e-04 - val_accuracy: 1.0000 - val_loss: 1.3026e-06
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.6878e-04 - val_accuracy: 1.0000 - val_loss: 8.4635e-07
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.2631e-04 - val_accuracy: 1.0000 - val_loss: 5.9255e-07
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.1729e-04 - val_accuracy: 1.0000 - val_loss: 4.1964e-07
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.0152e-04 - val_accuracy: 1.0000 - val_loss: 3.0932e-07
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 7.8843e-05 - val_accuracy: 1.0000 - val_loss: 2.3355e-07
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.9204e-05 - val_accuracy: 1.0000 - val_loss: 1.7907e-07
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.0526e-05 - val_accuracy: 1.0000 - val_loss: 1.4067e-07
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.9273e-05 - val_accuracy: 1.0000 - val_loss: 1.1176e-07
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.5907e-05 - val_accuracy: 1.0000 - val_loss: 9.0204e-08
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.0657e-05 - val_accuracy: 1.0000 - val_loss: 7.3358e-08
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 3.4111e-05 - val_accuracy: 1.0000 - val_loss: 6.1156e-08
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.3860e-05 - val_accuracy: 1.0000 - val_loss: 5.0749e-08
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.8302e-05 - val_accuracy: 1.0000 - val_loss: 4.2969e-08
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.5577e-05 - val_accuracy: 1.0000 - val_loss: 3.6370e-08
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.5083e-05 - val_accuracy: 1.0000 - val_loss: 3.0881e-08
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.0707e-05 - val_accuracy: 1.0000 - val_loss: 2.6727e-08
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.1035e-05 - val_accuracy: 1.0000 - val_loss: 2.2754e-08
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.0594e-05 - val_accuracy: 1.0000 - val_loss: 1.9531e-08
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.8621e-05 - val_accuracy: 1.0000 - val_loss: 1.7105e-08
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.5254e-05 - val_accuracy: 1.0000 - val_loss: 1.5020e-08
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.6140e-05 - val_accuracy: 1.0000 - val_loss: 1.3200e-08
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.3311e-05 - val_accuracy: 1.0000 - val_loss: 1.1704e-08
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 1.3518e-05 - val_accuracy: 1.0000 - val_loss: 1.0182e-08
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 1.1490e-05 - val_accuracy: 1.0000 - val_loss: 9.1244e-09
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.0981e-05 - val_accuracy: 1.0000 - val_loss: 8.1620e-09
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 1.0022e-05 - val_accuracy: 1.0000 - val_loss: 7.2979e-09
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.4685e-06 - val_accuracy: 1.0000 - val_loss: 6.5545e-09
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.7793e-06 - val_accuracy: 1.0000 - val_loss: 5.9171e-09
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 8.4807e-06 - val_accuracy: 1.0000 - val_loss: 5.3504e-09
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.3348e-06 - val_accuracy: 1.0000 - val_loss: 4.8615e-09
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 7.4595e-06 - val_accuracy: 1.0000 - val_loss: 4.4321e-09
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.8712e-06 - val_accuracy: 1.0000 - val_loss: 4.0341e-09
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.7232e-06 - val_accuracy: 1.0000 - val_loss: 3.6763e-09
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 6.7690e-06 - val_accuracy: 1.0000 - val_loss: 3.3553e-09
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.6134e-06 - val_accuracy: 1.0000 - val_loss: 3.0760e-09
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.2879e-06 - val_accuracy: 1.0000 - val_loss: 2.8371e-09
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.7170e-06 - val_accuracy: 1.0000 - val_loss: 2.5921e-09
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.8277e-06 - val_accuracy: 1.0000 - val_loss: 2.3905e-09
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 5.3439e-06 - val_accuracy: 1.0000 - val_loss: 2.1979e-09
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.1432e-06 - val_accuracy: 1.0000 - val_loss: 2.0301e-09
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.4378e-06 - val_accuracy: 1.0000 - val_loss: 1.8827e-09
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.8423e-06 - val_accuracy: 1.0000 - val_loss: 1.7237e-09
